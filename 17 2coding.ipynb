# %%
a = list(range(1,7))
b = [1, 2, 3, 4, 5, 6]
list1 = []
list2 = []
list3 = []
list4 = []
list5 = []
list6 = []
for i in a:
  for j in b:
    list1.append(i*j)

if 

print(list1)
print(list2)
print(list3)
print(list4)
print(list5)
print(list6)
# Out:
#   File "<ipython-input-25-b8815bdf4d74>", line 13
#     if
#        ^
# SyntaxError: invalid syntax
